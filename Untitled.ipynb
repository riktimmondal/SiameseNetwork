# %% [markdown]
# # IMPORT ALL LIBRARIES

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
#  Helper functions¶

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# Configuration Class

# %%
class Config():
    training_dir = "./data/faces/training/"
    testing_dir = "./data/faces/testing/"
    train_batch_size = 32
    train_number_epochs = 100

# %% [markdown]
# MODEL CLASS

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork,self).__init__()
        self.cnn1=nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1,4,kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            nn.Dropout2d(p=.2),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4,8,kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),
            nn.Dropout2d(p=.2),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(8,8,kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),
            nn.Dropout2d(p=.2),
        )
        
        self.fc1=nn.Sequential(
            nn.Linear(8*100*100,500),
            nn.ReLU(inplace=True),
            
            nn.Linear(500,500),
            nn.ReLU(inplace=True),
            
            nn.Linear(500,5)
            
        )
        
    def forward_once(self,x):
        output=self.cnn1(x)
        output=output.view(output.size()[0],-1)
        output=self.fc1(output)
        return output
    
    def forward(self,input1,input2):
        output1=self.forward_once(input1)
        output2=self.forward_once(input2)
        return output1,output2

# %% [markdown]
# CONTRRASTIVE LOSS

# %%
class ContrastiveLoss(nn.Module):
    
    def __init__(self,margin=2.0):
        super(ContrastiveLoss,self).__init__()
        self.margin=margin
        
    def forward(self,output1,output2,label):
        euclidean_distance=F.pairwise_distance(output1,output2)
        loss_contrastive=torch.mean((1-label)*torch.pow(euclidean_distance,2)+
                                   (label)*torch.pow(torch.clamp(self.margin-euclidean_distance,min=0.0),2))
        return loss_contrastive

# %% [markdown]
# DATASET LOADER FOR ANY TYPE OF DATASET

# %%
class SiameseNetworkDataset(Dataset):
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset=imageFolderDataset
        self.transform=transform
        self.should_invert=should_invert
        
    def __getitem__(self,index):
        img0_tuple=random.choice(self.imageFolderDataset.imgs)
        
        #print(type(img0_tuple))
        #print(img0_tuple[1])
        #print(img0_tuple[0])
        
        should_get_same_class=random.randint(0,1)  #making sure 50% images are in same classes
        if should_get_same_class:
            while True:
                #keep looping till same class image is found
                img1_tuple=random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            img1_tuple=random.choice(self.imageFolderDataset.imgs)
            
        img0=Image.open(img0_tuple[0])
        img1=Image.open(img1_tuple[0])
        img0=img0.convert("L")
        img1=img1.convert("L")
        
        if self.should_invert:
            img0=PIL.ImageOps.invert(img0)
            img1=PIL.ImageOps.invert(img1)
            
        if self.transform is not None:
            img0=self.transform(img0)
            img1=self.transform(img1)
            
        return img0,img1,torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# MAKING TRANNING DATALOADER

# %%
folder_dataset=dset.ImageFolder(root=Config.training_dir)
siamese_dataset=SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# Visualising some of the data

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)

example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]]

# %% [markdown]
# Training the Siamese Network

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)


net=SiameseNetwork().cuda()
criterion=ContrastiveLoss()
optimizer=optim.Adam(net.parameters(),lr=0.0005)

counter=[]
loss_history=[]
iteration_number=0

for epoch in range(0,Config.train_number_epochs):
    for i,data in enumerate(train_dataloader,0):
        img0,img1,label=data
        img0,img1,label=Variable(img0).cuda(),Variable(img1).cuda(),Variable(label).cuda()
        output1,output2=net(img0,img1)
        optimizer.zero_grad()
        loss_contrastive=criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i%10 == 0:
            print("Epoch num {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number+=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())

show_plot(counter,loss_history)
# Out:
# Epoch num 0
#  Current loss 1.4273786544799805
#
# Epoch num 0
#  Current loss 1.3387668132781982
#
# Epoch num 1
#  Current loss 1.3736217021942139
#
# Epoch num 1
#  Current loss 1.1746104955673218
#
# Epoch num 2
#  Current loss 1.189805269241333
#
# Epoch num 2
#  Current loss 1.405561089515686
#
# Epoch num 3
#  Current loss 1.3075441122055054
#
# Epoch num 3
#  Current loss 1.0732102394104004
#
# Epoch num 4
#  Current loss 1.146191954612732
#
# Epoch num 4
#  Current loss 1.1649327278137207
#
# Epoch num 5
#  Current loss 1.1699063777923584
#
# Epoch num 5
#  Current loss 1.1058298349380493
#
# Epoch num 6
#  Current loss 1.0944499969482422
#
# Epoch num 6
#  Current loss 1.1187959909439087
#
# Epoch num 7
#  Current loss 1.0543248653411865
#
# Epoch num 7
#  Current loss 1.166707158088684
#
# Epoch num 8
#  Current loss 1.1760847568511963
#
# Epoch num 8
#  Current loss 1.1449904441833496
#
# Epoch num 9
#  Current loss 1.0806641578674316
#
# Epoch num 9
#  Current loss 1.111127495765686
#
# Epoch num 10
#  Current loss 1.1508827209472656
#
# Epoch num 10
#  Current loss 1.1431946754455566
#
# Epoch num 11
#  Current loss 1.155631422996521
#
# Epoch num 11
#  Current loss 1.0838254690170288
#
# Epoch num 12
#  Current loss 1.4081478118896484
#
# Epoch num 12
#  Current loss 1.1431854963302612
#
# Epoch num 13
#  Current loss 1.1777769327163696
#
# Epoch num 13
#  Current loss 1.1231895685195923
#
# Epoch num 14
#  Current loss 1.2321449518203735
#
# Epoch num 14
#  Current loss 1.1704167127609253
#
# Epoch num 15
#  Current loss 1.0961846113204956
#
# Epoch num 15
#  Current loss 1.1143912076950073
#
# Epoch num 16
#  Current loss 1.1155622005462646
#
# Epoch num 16
#  Current loss 1.1520813703536987
#
# Epoch num 17
#  Current loss 1.0832383632659912
#
# Epoch num 17
#  Current loss 1.134307861328125
#
# Epoch num 18
#  Current loss 1.010995626449585
#
# Epoch num 18
#  Current loss 1.0776798725128174
#
# Epoch num 19
#  Current loss 1.1780413389205933
#
# Epoch num 19
#  Current loss 1.1362576484680176
#
# Epoch num 20
#  Current loss 1.1087238788604736
#
# Epoch num 20
#  Current loss 1.05576491355896
#
# Epoch num 21
#  Current loss 1.0488927364349365
#
# Epoch num 21
#  Current loss 1.2237052917480469
#
# Epoch num 22
#  Current loss 1.0961525440216064
#
# Epoch num 22
#  Current loss 1.1595349311828613
#
# Epoch num 23
#  Current loss 1.1152422428131104
#
# Epoch num 23
#  Current loss 1.0779526233673096
#
# Epoch num 24
#  Current loss 1.1470437049865723
#
# Epoch num 24
#  Current loss 1.2517699003219604
#
# Epoch num 25
#  Current loss 0.9850547313690186
#
# Epoch num 25
#  Current loss 1.1167418956756592
#
# Epoch num 26
#  Current loss 1.1686747074127197
#
# Epoch num 26
#  Current loss 1.0517113208770752
#
# Epoch num 27
#  Current loss 1.145953893661499
#
# Epoch num 27
#  Current loss 1.169041633605957
#
# Epoch num 28
#  Current loss 1.095946192741394
#
# Epoch num 28
#  Current loss 1.1021153926849365
#
# Epoch num 29
#  Current loss 1.1762278079986572
#
# Epoch num 29
#  Current loss 1.1349143981933594
#
# Epoch num 30
#  Current loss 1.076941728591919
#
# Epoch num 30
#  Current loss 1.153426170349121
#
# Epoch num 31
#  Current loss 1.1395364999771118
#
# Epoch num 31
#  Current loss 1.1349583864212036
#
# Epoch num 32
#  Current loss 1.112858533859253
#
# Epoch num 32
#  Current loss 1.2030673027038574
#
# Epoch num 33
#  Current loss 1.0329022407531738
#
# Epoch num 33
#  Current loss 1.1653387546539307
#
# Epoch num 34
#  Current loss 1.1102244853973389
#
# Epoch num 34
#  Current loss 1.1475504636764526
#
# Epoch num 35
#  Current loss 1.183133602142334
#
# Epoch num 35
#  Current loss 1.1150304079055786
#
# Epoch num 36
#  Current loss 1.096402883529663
#
# Epoch num 36
#  Current loss 1.1516003608703613
#
# Epoch num 37
#  Current loss 1.07291841506958
#
# Epoch num 37
#  Current loss 0.8994414210319519
#
# Epoch num 38
#  Current loss 1.1606354713439941
#
# Epoch num 38
#  Current loss 1.1634728908538818
#
# Epoch num 39
#  Current loss 1.2121909856796265
#
# Epoch num 39
#  Current loss 1.1219820976257324
#
# Epoch num 40
#  Current loss 1.0440083742141724
#
# Epoch num 40
#  Current loss 1.0466289520263672
#
# Epoch num 41
#  Current loss 1.1128489971160889
#
# Epoch num 41
#  Current loss 1.1357312202453613
#
# Epoch num 42
#  Current loss 1.1427114009857178
#
# Epoch num 42
#  Current loss 1.1174311637878418
#
# Epoch num 43
#  Current loss 1.0950567722320557
#
# Epoch num 43
#  Current loss 1.1313354969024658
#
# Epoch num 44
#  Current loss 1.1063332557678223
#
# Epoch num 44
#  Current loss 1.0924032926559448
#
# Epoch num 45
#  Current loss 1.0604814291000366
#
# Epoch num 45
#  Current loss 1.1296181678771973
#
# Epoch num 46
#  Current loss 1.1319124698638916
#
# Epoch num 46
#  Current loss 1.1105034351348877
#
# Epoch num 47
#  Current loss 1.1266422271728516
#
# Epoch num 47
#  Current loss 1.085059642791748
#
# Epoch num 48
#  Current loss 1.0907057523727417
#
# Epoch num 48
#  Current loss 1.1421623229980469
#
# Epoch num 49
#  Current loss 1.1122791767120361
#
# Epoch num 49
#  Current loss 1.1554861068725586
#
# Epoch num 50
#  Current loss 1.146405816078186
#
# Epoch num 50
#  Current loss 1.1138581037521362
#
# Epoch num 51
#  Current loss 1.2366106510162354
#
# Epoch num 51
#  Current loss 1.056161880493164
#
# Epoch num 52
#  Current loss 0.9630188941955566
#
# Epoch num 52
#  Current loss 1.2213863134384155
#
# Epoch num 53
#  Current loss 1.1497609615325928
#
# Epoch num 53
#  Current loss 1.0966886281967163
#
# Epoch num 54
#  Current loss 1.1025160551071167
#
# Epoch num 54
#  Current loss 1.0864737033843994
#
# Epoch num 55
#  Current loss 1.0449016094207764
#
# Epoch num 55
#  Current loss 1.0501127243041992
#
# Epoch num 56
#  Current loss 1.0544568300247192
#
# Epoch num 56
#  Current loss 1.1383733749389648
#
# Epoch num 57
#  Current loss 0.9676434397697449
#
# Epoch num 57
#  Current loss 1.1431883573532104
#
# Epoch num 58
#  Current loss 1.0892165899276733
#
# Epoch num 58
#  Current loss 1.067551851272583
#
# Epoch num 59
#  Current loss 1.0945504903793335
#
# Epoch num 59
#  Current loss 1.0480401515960693
#
# Epoch num 60
#  Current loss 1.0758144855499268
#
# Epoch num 60
#  Current loss 1.1068906784057617
#
# Epoch num 61
#  Current loss 1.1599525213241577
#
# Epoch num 61
#  Current loss 1.0918604135513306
#
# Epoch num 62
#  Current loss 1.1849991083145142
#
# Epoch num 62
#  Current loss 1.0064506530761719
#
# Epoch num 63
#  Current loss 1.1002261638641357
#
# Epoch num 63
#  Current loss 1.1344497203826904
#
# Epoch num 64
#  Current loss 1.0850780010223389
#
# Epoch num 64
#  Current loss 1.064023494720459
#
# Epoch num 65
#  Current loss 1.1146550178527832
#
# Epoch num 65
#  Current loss 1.0927269458770752
#
# Epoch num 66
#  Current loss 1.154213547706604
#
# Epoch num 66
#  Current loss 1.2254401445388794
#
# Epoch num 67
#  Current loss 1.1836891174316406
#
# Epoch num 67
#  Current loss 0.9262844920158386
#
# Epoch num 68
#  Current loss 1.0821233987808228
#
# Epoch num 68
#  Current loss 1.1222660541534424
#
# Epoch num 69
#  Current loss 1.1395504474639893
#
# Epoch num 69
#  Current loss 1.1530334949493408
#
# Epoch num 70
#  Current loss 1.1474463939666748
#
# Epoch num 70
#  Current loss 1.1096782684326172
#
# Epoch num 71
#  Current loss 1.1330063343048096
#
# Epoch num 71
#  Current loss 1.1653481721878052
#
# Epoch num 72
#  Current loss 1.1416423320770264
#
# Epoch num 72
#  Current loss 1.0858268737792969
#
# Epoch num 73
#  Current loss 1.1375617980957031
#
# Epoch num 73
#  Current loss 1.0999629497528076
#
# Epoch num 74
#  Current loss 1.0860211849212646
#
# Epoch num 74
#  Current loss 1.0779800415039062
#
# Epoch num 75
#  Current loss 1.1200854778289795
#
# Epoch num 75
#  Current loss 1.1060528755187988
#
# Epoch num 76
#  Current loss 1.1083462238311768
#
# Epoch num 76
#  Current loss 0.9157530069351196
#
# Epoch num 77
#  Current loss 1.0936979055404663
#
# Epoch num 77
#  Current loss 1.0601165294647217
#
# Epoch num 78
#  Current loss 1.0594544410705566
#
# Epoch num 78
#  Current loss 1.204716444015503
#
# Epoch num 79
#  Current loss 1.0878989696502686
#
# Epoch num 79
#  Current loss 1.0128906965255737
#
# Epoch num 80
#  Current loss 1.051919937133789
#
# Epoch num 80
#  Current loss 1.1504013538360596
#
# Epoch num 81
#  Current loss 1.06575345993042
#
# Epoch num 81
#  Current loss 1.214742660522461
#
# Epoch num 82
#  Current loss 1.0961614847183228
#
# Epoch num 82
#  Current loss 1.0655722618103027
#
# Epoch num 83
#  Current loss 1.062211513519287
#
# Epoch num 83
#  Current loss 1.0541446208953857
#
# Epoch num 84
#  Current loss 1.0273469686508179
#
# Epoch num 84
#  Current loss 1.064407467842102
#
# Epoch num 85
#  Current loss 1.0595381259918213
#
# Epoch num 85
#  Current loss 1.0735031366348267
#
# Epoch num 86
#  Current loss 1.0443336963653564
#
# Epoch num 86
#  Current loss 1.1184289455413818
#
# Epoch num 87
#  Current loss 1.1000913381576538
#
# Epoch num 87
#  Current loss 1.1185808181762695
# Epoch num 88
#  Current loss 1.1058318614959717
#
# Epoch num 88
#  Current loss 1.2268686294555664
#
# Epoch num 89
#  Current loss 1.0722439289093018
#
# Epoch num 89
#  Current loss 1.1498405933380127
#
# Epoch num 90
#  Current loss 1.18019437789917
#
# Epoch num 90
#  Current loss 1.0877211093902588
#
# Epoch num 91
#  Current loss 1.0320940017700195
#
# Epoch num 91
#  Current loss 1.0922317504882812
#
# Epoch num 92
#  Current loss 1.0500128269195557
#
# Epoch num 92
#  Current loss 1.1335633993148804
#
# Epoch num 93
#  Current loss 1.0102481842041016
#
# Epoch num 93
#  Current loss 1.144394874572754
#
# Epoch num 94
#  Current loss 1.1347179412841797
#
# Epoch num 94
#  Current loss 1.2287564277648926
#
# Epoch num 95
#  Current loss 1.1335405111312866
#
# Epoch num 95
#  Current loss 1.0993999242782593
#
# Epoch num 96
#  Current loss 1.0672178268432617
#
# Epoch num 96
#  Current loss 1.2100212574005127
#
# Epoch num 97
#  Current loss 1.1398200988769531
#
# Epoch num 97
#  Current loss 1.1217458248138428
#
# Epoch num 98
#  Current loss 1.1240235567092896
#
# Epoch num 98
#  Current loss 1.0477893352508545
#
# Epoch num 99
#  Current loss 1.0721757411956787
#
# Epoch num 99
#  Current loss 1.1166455745697021

# %% [markdown]
# Testing the network

# %%
folder_dataset_test=dset.ImageFolder(root=Config.testing_dir)
siamese_dataset=SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                     transform=transforms.Compose([transforms.Scale((100,100)),
                                                                   transforms.ToTensor()
                                                                   ])
                                     ,should_invert=False)
test_dataloader=DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter=iter(test_dataloader)
x0,_,_=next(dataiter)

for i in range(10):
    _,x1,label2=next(dataiter)
    concatenated=torch.cat((x0,x1),0)
    
    output1,output2=net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.cpu().data.numpy()[0]))
# Out:
# /home/riktim/.local/lib/python3.6/site-packages/torchvision/transforms/transforms.py:188: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   "please use transforms.Resize instead.")
